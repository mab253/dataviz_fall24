# %%
import random

classPeople = ["Saar T.", "Rubiel A.", "Aditya M.", "Sai Vamsee B.", "Allen L.", "Sardor H.", "Constantine S.", "Jason J.", "Lisha R.", "Matthew G.", "Safal T."]
weeks = [[3], [4], [7], [8], [9], [10], [11], [12]]

random.shuffle(classPeople)

studentIndex = 0;
for week in weeks:
  for i in range(3):
    week.append(classPeople[studentIndex])
    studentIndex += 1

    if studentIndex >= len(classPeople):
      studentIndex = 0

for week in weeks:
  print(week)
# Out:
# [3, 'Sardor H.', 'Saar T.', 'Safal T.']
# [4, 'Sai Vamsee B.', 'Lisha R.', 'Jason J.']
# [7, 'Aditya M.', 'Constantine S.', 'Rubiel A.']
# [8, 'Matthew G.', 'Allen L.', 'Sardor H.']
# [9, 'Saar T.', 'Safal T.', 'Sai Vamsee B.']
# [10, 'Lisha R.', 'Jason J.', 'Aditya M.']
# [11, 'Constantine S.', 'Rubiel A.', 'Matthew G.']
# [12, 'Allen L.', 'Sardor H.', 'Saar T.']

# %%
# warm-up with pandas: import, and DIY dataframe

import pandas as pd

# we need to load matplotlib!
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.DataFrame({
    'borough_name': ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
    'population_2020': [2736074, 1694251, 2405464, 495747, 1472654],
    'major_airport': [False, False, True, False, False]
})

# use bracket notation to select column, index
df["population_2020"][0]
# Out:
# 2736074

# %%
# install the dataset via pip, python package manager
# !pip install palmerpenguins
from palmerpenguins import load_penguins_raw

# load dataframe into variable called penguins
penguins = load_penguins_raw()

# %%
penguins.head()

# hmm, what is culmen?
# more context on this data @ the source: https://allisonhorst.github.io/palmerpenguins/articles/art.html
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
# ...

# %%
# let's rename that column name, culmen
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html

# dataframe = dataframe.rename(columns={'old_column_name': 'new_column_name'})
penguins = penguins.rename(columns={'Culmen Length (mm)': 'Bill Length (mm)'})
penguins = penguins.rename(columns={'Culmen Depth (mm)': 'Bill Depth (mm)'})

penguins.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
# ...

# %%
# get rows, columns
penguins.shape
# Out:
# (344, 17)

# %%
# summarize columns, non-null counts, and data type
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Bill Length (mm)     342 non-null    float64
#  10  Bill Depth (mm)      342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  333 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
# get statistics for each quantitative column/attribute
penguins.describe()
# Out:
#        Sample Number  Bill Length (mm)  Bill Depth (mm)  Flipper Length (mm)  \
# count     344.000000        342.000000       342.000000           342.000000
# mean       63.151163         43.921930        17.151170           200.915205
# std        40.430199          5.459584         1.974793            14.061714
# min         1.000000         32.100000        13.100000           172.000000
# 25%        29.000000         39.225000        15.600000           190.000000
# 50%        58.000000         44.450000        17.300000           197.000000
# 75%        95.250000         48.500000        18.700000           213.000000
# max       152.000000         59.600000        21.500000           231.000000
#
#        Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# count     342.000000         330.000000         331.000000
# mean     4201.754386           8.733382         -25.686292
# std       801.954536           0.551770           0.793961
# ...

# %%
# write to csv, to view in another platform
penguins.to_csv('penguins.csv')

# %%
# explore: how many non-NA (blank, undefined, missing) values, per column?
# also part of .info()
penguins.count()
# Out:
# studyName              344
# Sample Number          344
# Species                344
# Region                 344
# Island                 344
# Stage                  344
# Individual ID          344
# Clutch Completion      344
# Date Egg               344
# Bill Length (mm)       342
# Bill Depth (mm)        342
# Flipper Length (mm)    342
# Body Mass (g)          342
# Sex                    333
# Delta 15 N (o/oo)      330
# Delta 13 C (o/oo)      331
# Comments                54
# dtype: int64

# %%
# hmm, values don't all add to 344 ... show the missing values?
print(penguins.isna().sum())
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Bill Length (mm)         2
# Bill Depth (mm)          2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     11
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               290
# dtype: int64

# %%
# explore: how many different values for the 'island' column/attribute?
penguins['Island'].value_counts()
# Out:
# Island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
# how many unique values for different columns?
print(penguins['Sex'].nunique())
print(penguins['Island'].nunique())
print(penguins['Bill Length (mm)'].nunique())
# Out:
# 2
# 3
# 164

# %%
# let's sort by flipper length
# documentation on sorting: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html

penguins.sort_values("Flipper Length (mm)", ascending=True).head()
# Out:
#     studyName  Sample Number                              Species  Region  \
# 28    PAL0708             29  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 20    PAL0708             21  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 122   PAL0910            123  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 30    PAL0708             31  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 31    PAL0708             32  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  \
# 28      Biscoe  Adult, 1 Egg Stage         N18A1                No
# 20      Biscoe  Adult, 1 Egg Stage         N11A1               Yes
# 122  Torgersen  Adult, 1 Egg Stage         N67A1               Yes
# 30       Dream  Adult, 1 Egg Stage         N21A1               Yes
# 31       Dream  Adult, 1 Egg Stage         N21A2               Yes
#
#        Date Egg  Bill Length (mm)  Bill Depth (mm)  Flipper Length (mm)  \
# ...

# %%
# what is the standard deviation of the quantiataive attributes - how far are values from the mean?
# what happens when skipna = False?

penguins.std(numeric_only=True, skipna=True)
# Out:
# Sample Number           40.430199
# Bill Length (mm)         5.459584
# Bill Depth (mm)          1.974793
# Flipper Length (mm)     14.061714
# Body Mass (g)          801.954536
# Delta 15 N (o/oo)        0.551770
# Delta 13 C (o/oo)        0.793961
# dtype: float64

# %%
# what about creating a smaller DataFrame, just bill length vs species?

bill_length_species = penguins[["Bill Length (mm)", "Species"]]

bill_length_species.sort_values("Bill Length (mm)", ascending=False).head(10)
# Out:
#      Bill Length (mm)                                    Species
# 185              59.6          Gentoo penguin (Pygoscelis papua)
# 293              58.0  Chinstrap penguin (Pygoscelis antarctica)
# 253              55.9          Gentoo penguin (Pygoscelis papua)
# 339              55.8  Chinstrap penguin (Pygoscelis antarctica)
# 267              55.1          Gentoo penguin (Pygoscelis papua)
# 215              54.3          Gentoo penguin (Pygoscelis papua)
# 307              54.2  Chinstrap penguin (Pygoscelis antarctica)
# 315              53.5  Chinstrap penguin (Pygoscelis antarctica)
# 259              53.4          Gentoo penguin (Pygoscelis papua)
# 305              52.8  Chinstrap penguin (Pygoscelis antarctica)

# %%
# if we are going to visualize this, we could choose to get rid of NA outliers

bill_length_species = bill_length_species.dropna()
bill_length_species.shape

# more context on missing values: https://jakevdp.github.io/PythonDataScienceHandbook/03.04-missing-values.html
# Out:
# (342, 2)

# %%
# let's look @ the mean of the culmen length, by species

bill_length_species.groupby("Species").mean()

# documentation on groupby: https://pandas.pydata.org/docs/user_guide/groupby.html
# Out:
#                                            Bill Length (mm)
# Species
# Adelie Penguin (Pygoscelis adeliae)               38.791391
# Chinstrap penguin (Pygoscelis antarctica)         48.833824
# Gentoo penguin (Pygoscelis papua)                 47.504878

# %%
# let's start with a scatter plot of just this data, species + culmen length
# working with the matplotlib defaults ...

plt.scatter(bill_length_species["Species"], bill_length_species["Bill Length (mm)"])

# %%
# but if I want to show each species in a different color, I should filter my data

# make a list of all the unique values in the "Species" column, full names
species = bill_length_species["Species"].unique()
print(species)

# filter: just DataFrames of culmen length vs. species, one DataFrame per species
adelie = bill_length_species[bill_length_species["Species"] == 'Adelie Penguin (Pygoscelis adeliae)']
gentoo = bill_length_species[bill_length_species["Species"] == species[1]]
chinstrap = bill_length_species[bill_length_species["Species"] == species[2]]

# my data frame with head!!
chinstrap.head()
# Out:
# ['Adelie Penguin (Pygoscelis adeliae)' 'Gentoo penguin (Pygoscelis papua)'
#  'Chinstrap penguin (Pygoscelis antarctica)']
#      Bill Length (mm)                                    Species
# 276              46.5  Chinstrap penguin (Pygoscelis antarctica)
# 277              50.0  Chinstrap penguin (Pygoscelis antarctica)
# 278              51.3  Chinstrap penguin (Pygoscelis antarctica)
# 279              45.4  Chinstrap penguin (Pygoscelis antarctica)
# 280              52.7  Chinstrap penguin (Pygoscelis antarctica)

# %%
# remember: plt.scatter(x, y, options)
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

plt.scatter(adelie["Species"], adelie["Bill Length (mm)"], color="Orange", alpha = 0.5, s = 150)
plt.scatter(gentoo["Species"], gentoo["Bill Length (mm)"], color="Teal", alpha = 0.5, s = 150)
plt.scatter(chinstrap["Species"], chinstrap["Bill Length (mm)"], color="Purple", alpha = 0.5, s = 150)

# %%
# to examine the mean along with the scatter, let's add a boxplot to each species
# matplotlib docs: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html#

y_data = [adelie["Bill Length (mm)"], gentoo["Bill Length (mm)"], chinstrap["Bill Length (mm)"]]

# remember the pattern! plt.type(data, options)
plt.boxplot(y_data, positions=[0, 1, 2])

# pattern: plt.scatter(x, y, options)
# to match the box plots to the scatter plots, we assign:
# adelie = 0, gentoo = 1, chinstrap = 2
# x values here need to be a list the same length as the y list
plt.scatter([0]*len(adelie), adelie["Bill Length (mm)"], color="Orange", alpha = 0.5, s = 100)
plt.scatter([1]*len(gentoo), gentoo["Bill Length (mm)"], color="Teal", alpha = 0.5, s = 100)
plt.scatter([2]*len(chinstrap), chinstrap["Bill Length (mm)"], color="Purple", alpha = 0.5, s = 100)

# %%
# let's do some data transformation, and "jitter" the dots

plt.boxplot(y_data, positions=[0, 1, 2])

import random

# for each species, I want to have an x_data list, small random numbers in a range near their x value
# the list of x values needs to be the same length as the list of y values
x_adelie = [random.uniform(-0.1, 0.1) + 0 for numbers in range(len(adelie))]
print(x_adelie)

x_gentoo = [random.uniform(-0.1, 0.1) + 1 for numbers in range(len(gentoo))]
x_chinstrap = [random.uniform(-0.1, 0.1) + 2 for numbers in range(len(chinstrap))]

plt.scatter(x_adelie, adelie["Bill Length (mm)"], color="Orange", alpha = 0.3, s = 80)
plt.scatter(x_gentoo, gentoo["Bill Length (mm)"], color="Teal", alpha = 0.3, s = 80)
plt.scatter(x_chinstrap, chinstrap["Bill Length (mm)"], color="Purple", alpha = 0.3, s = 80)
# Out:
# [0.06192008300927451, 0.0809403767044646, -0.07157082152082604, 0.06879903289347969, -0.09209399440204545, -0.061435586070385066, 0.07119908865468302, -0.09052243205301003, 0.08495798179224245, -0.0593864093944764, -0.0054183924753564705, -0.08230346896592067, -0.03332809706348963, -0.032919248086131336, -0.07720931777265108, 0.08593843373824667, -0.09704243661419845, 0.0059682723083555045, -0.05690178668196331, -0.014898895318747996, -0.06804931284050134, -0.0949121509620992, -0.0966541524424801, -0.008676307956051926, -0.008777827768269922, -0.061220168708893, -0.02058496710100459, 0.04571007395696958, -0.043181964094374206, 0.008170254464099733, -0.004665958617883284, 0.09772826509937022, 0.09632272479900009, -0.0511378592097431, -0.09174433377422414, -0.0690496342011346, 0.019642438905522683, 0.039818050173510006, 0.04394257252365549, 0.019482640148945116, 0.009402949031983507, -0.04739964637703702, 0.058461575313448866, -0.07756123867144277, -0.0006321268819127895, 0.00481475245
# ...

# %%
# let's see a violin plot to this data
# documentation: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.violinplot.html

violins = plt.violinplot(
    y_data,
    positions=[0, 1, 2],
    widths=0.40,
    bw_method="silverman",
    showmeans=False,
    showmedians=False,
    showextrema=False
)

# %%
# now we ADD the violin to the outside

# and style the median lines in the box plot
plt.boxplot(y_data, positions=[0, 1, 2], medianprops={"color": "Red", "linewidth": 2})

plt.scatter(x_adelie, adelie["Bill Length (mm)"], color="Orange", alpha = 0.3, s = 80)
plt.scatter(x_gentoo, gentoo["Bill Length (mm)"], color="Teal", alpha = 0.3, s = 80)
plt.scatter(x_chinstrap, chinstrap["Bill Length (mm)"], color="Purple", alpha = 0.3, s = 80)

violins = plt.violinplot(y_data,positions=[0, 1, 2],widths=0.40,bw_method="silverman")

# let's change the background fill to transparent - or, facecolor to 'none' for each violin plot
for body in violins['bodies']:
    body.set_facecolor('none')
    body.set_edgecolor('Black')

# %%
# reproducing the plot ...
plt.figure(figsize=(14, 10))
# figsize = inches!

plt.boxplot(y_data, positions=[0, 1, 2], medianprops={"color": "Red", "linewidth": 2})

plt.scatter(x_adelie, adelie["Bill Length (mm)"], color="Orange", alpha = 0.3, s = 80)
plt.scatter(x_gentoo, gentoo["Bill Length (mm)"], color="Teal", alpha = 0.3, s = 80)
plt.scatter(x_chinstrap, chinstrap["Bill Length (mm)"], color="Purple", alpha = 0.3, s = 80)

#violins = plt.violinplot(y_data,positions=[0, 1, 2],widths=0.40,bw_method="silverman")

#for body in violins['bodies']:
#    body.set_facecolor('none')
#    body.set_edgecolor('Black')

# but let's clean up the axes, titles, text, font, etc.!
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html
plt.rcParams["font.family"] = "monospace"
plt.xticks([0, 1, 2], ["Adelie", "Gentoo", "Chinstrap"], rotation=0, ha='center')
plt.ylabel("Culmen Length (mm)")
plt.xlabel("Penguin Species")
plt.title("\nDistribution of Bill Length Across Penguin Species\n", pad=10, fontsize=18)

# and save it
plt.savefig("violin.png", dpi=500, format="png")

# %%
# nice!
# now ... let's go back to the larger penguin dataset
# and plot flipper length vs. body mass, for each of the 3 species

plt.scatter(penguins["Flipper Length (mm)"], penguins["Body Mass (g)"])

# %%
# ok ... but we want to filter the dataset to get 3 species, differentiated

# first getting a smaller dataframe
flipper_mass = penguins[["Flipper Length (mm)", "Body Mass (g)", "Species"]]
flipper_mass.head()
# Out:
#    Flipper Length (mm)  Body Mass (g)                              Species
# 0                181.0         3750.0  Adelie Penguin (Pygoscelis adeliae)
# 1                186.0         3800.0  Adelie Penguin (Pygoscelis adeliae)
# 2                195.0         3250.0  Adelie Penguin (Pygoscelis adeliae)
# 3                  NaN            NaN  Adelie Penguin (Pygoscelis adeliae)
# 4                193.0         3450.0  Adelie Penguin (Pygoscelis adeliae)

# %%
# removing na values ...
flipper_mass.dropna()
flipper_mass.shape
# Out:
# (344, 3)

# %%
# make filtered dataframes for each species: i.e., an adelie table with only flipper length and body mass

adelie_flip = flipper_mass[flipper_mass["Species"] == species[0]]
gentoo_flip = flipper_mass[flipper_mass["Species"] == species[1]]
chinstrap_flip = flipper_mass[flipper_mass["Species"] == species[2]]

adelie_flip.head(1)
# Out:
#    Flipper Length (mm)  Body Mass (g)                              Species
# 0                181.0         3750.0  Adelie Penguin (Pygoscelis adeliae)

# %%
plt.figure(figsize=(10, 8))

# markers! https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers

plt.scatter(adelie_flip["Flipper Length (mm)"], adelie_flip["Body Mass (g)"], color = "Orange", marker="o", label = "adelie")
plt.scatter(gentoo_flip["Flipper Length (mm)"], gentoo_flip["Body Mass (g)"], color = "Teal", marker="v", label = "gentoo")
plt.scatter(chinstrap_flip["Flipper Length (mm)"], chinstrap_flip["Body Mass (g)"], color = "Purple", marker="s", label = "chinstrap")

# note: we could loop these, but we are spelling them out for now

plt.legend()

plt.ylabel("Body Mass (g)")
plt.xlabel("Flipper Length (mm)")
plt.title("\nFlipper Length and Body Mass\nfor 3 Penguin Species, Palmer\n", pad=6, fontsize=18)
# Out:
# Text(0.5, 1.0, '\nFlipper Length and Body Mass\nfor 3 Penguin Species, Palmer\n')

# %%
# 📄 documentation cheatsheet!

# bar chart: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# histogram: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# titles: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html

# axis labels: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html

# colors: https://matplotlib.org/stable/tutorials/colors/colors.html

# annotations: https://matplotlib.org/stable/gallery/text_labels_and_annotations/annotation_basic.html

# fonts: https://matplotlib.org/stable/gallery/text_labels_and_annotations/fonts_demo_kw.html

# more fonts: https://matplotlib.org/stable/gallery/text_labels_and_annotations/font_family_rc.html

# %%
# now on your own!

# using the penguins dataframe, can you make a histogram for the body mass attribute, where the plot shows 3 species in different colors?
# make sure to label your axes and add a title 🎨

# %%
plt.hist(penguins[penguins["Species"] == species[0]]["Body Mass (g)"], color="Orange", alpha = 0.8)
plt.hist(penguins[penguins["Species"] == species[1]]["Body Mass (g)"], color="Teal", alpha = 0.8)
plt.hist(penguins[penguins["Species"] == species[2]]["Body Mass (g)"], color="Purple", alpha = 0.8)

plt.title("Distribution of Body Mass (g) Across 3 Species of Penguins")
plt.xlabel("Body Mass (g)")
plt.ylabel("# of Penguins")

# https://allisonhorst.github.io/palmerpenguins/articles/examples.html
# Out:
# Text(0, 0.5, '# of Penguins')

# %%
# create a bar chart, with (at least) 2 variables of your choice
# (how will you get the counts for the y-axis?)
# make sure to label your axes and add a title 🎨

islands_only = penguins['Island'].value_counts().reset_index()
islands_only.columns = ['Island', 'Count']
bar_colors = ["Tomato", "Orange", "Fuchsia"]
plt.bar(islands_only["Island"], islands_only["Count"], color=bar_colors)
penguins["Island"].value_counts()

plt.title("\nNumber of Penguins in Palmer Penguins Dataset\nAt 3 Different Islands", pad=20)
plt.xlabel("\nIslands in Palmer Archepelago, Antarctica")
plt.ylabel("# of Penguins")
# Out:
# Text(0, 0.5, '# of Penguins')

# %% [markdown]
# **🧊🐧 citations:**
# - violin inspiration: https://python-graph-gallery.com/web-ggbetweenstats-with-matplotlib/ Tuo Wang, Tomas Capretto
# - original dataset and examples: https://allisonhorst.github.io/palmerpenguins/index.html
# - palmerpenguins python package: https://github.com/mcnakhaee/palmerpenguins
# - Brian Byrne [notebook](https://colab.research.google.com/drive/1RUzNHKpLCGuik_hpVLfto5bSH_KFaqJb) and [video](https://www.youtube.com/watch?v=qzW-Zx4HIK0)
# - on the dataset: https://www.baseten.co/blog/data-curiosity-move-over-ames-its-palmer-penguin-time
